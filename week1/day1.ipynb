# %%
import os
from dotenv import load_dotenv
from scraper import fetch_website_contents
from IPython.display import Markdown, display
import google.generativeai as genai
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
#       2 from dotenv import load_dotenv
# ----> 3 from scraper import fetch_website_contents
#       4 from IPython.display import Markdown, display
#       5 import google.generativeai as genai
#
# ImportError: cannot import name 'fetch_website_contents' from 'scraper' (/workspaces/llm-engineering/.venv/lib/python3.12/site-packages/scraper/__init__.py)
