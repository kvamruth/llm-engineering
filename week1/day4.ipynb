# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-5")
tokens = encoding.encode("Using tiktoken to get tokenization for OpenAi's model.")

# %%
# print(tokens)
for token in tokens:
    print(f"Token: {token}, Text: {encoding.decode([token])}")
# Out:
# Token: 24849, Text: Using
# Token: 260, Text:  t
# Token: 8251, Text: ikt
# Token: 2488, Text: oken
# Token: 316, Text:  to
# Token: 717, Text:  get
# Token: 6602, Text:  token
# Token: 2860, Text: ization
# Token: 395, Text:  for
# Token: 7788, Text:  Open
# Token: 61169, Text: Ai
# Token: 885, Text: 's
# Token: 2359, Text:  model
# Token: 13, Text: .
